# %% [markdown]
# # Homework 3 | Survival Analysis | Anahit Manukyan

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from lifelines import WeibullFitter,\
                      ExponentialFitter,\
                      LogNormalFitter,\
                      LogLogisticFitter,\
                      WeibullAFTFitter,\
                      LogNormalAFTFitter,\
                      LogLogisticAFTFitter

# %%
df = pd.read_csv('telco.csv')
df.head(5)
# Out:
#    ID  region  tenure  age    marital  address  income  \
# 0   1  Zone 2      13   44    Married        9      64
# 1   2  Zone 3      11   33    Married        7     136
# 2   3  Zone 3      68   52    Married       24     116
# 3   4  Zone 2      33   33  Unmarried       12      33
# 4   5  Zone 2      23   30    Married        9      30
#
#                              ed retire  gender voice internet forward  \
# 0                College degree     No    Male    No       No     Yes
# 1     Post-undergraduate degree     No    Male   Yes       No     Yes
# 2  Did not complete high school     No  Female    No       No      No
# 3            High school degree     No  Female    No       No      No
# 4  Did not complete high school     No    Male    No       No     Yes
#
#          custcat churn
# 0  Basic service   Yes
# 1  Total service   Yes
# 2   Plus service    No
# 3  Basic service   Yes
# 4   Plus service    No

# %%
# indexing by ID
df.set_index('ID', inplace=True)

# %%
# churn: yes-1, no-0
df['churn'] = pd.Series(np.where(df.churn.values == "Yes", 1, 0), df.index)

# %%
# encoding the categorical variables into dummies: 1,0
encode_cols = ['region', 'marital', 'ed', 'retire', 'gender', 'voice', 'internet', 'forward', 'custcat']
survival_df = pd.get_dummies(df, columns=encode_cols, prefix=encode_cols, drop_first=True)
#we cannot have zeros we will make thos 0.0000001
survival_df["tenure"] = np.where(survival_df["tenure"] == 0, 0.000001, survival_df["tenure"])
survival_df.head()
# Out:
#     tenure  age  address  income  churn  region_Zone 2  region_Zone 3  \
# ID
# 1     13.0   44        9      64      1           True          False
# 2     11.0   33        7     136      1          False           True
# 3     68.0   52       24     116      0          False           True
# 4     33.0   33       12      33      1           True          False
# 5     23.0   30        9      30      0           True          False
#
#     marital_Unmarried  ed_Did not complete high school  ed_High school degree  \
# ID
# 1               False                            False                  False
# 2               False                            False                  False
# 3               False                             True                  False
# 4                True                            False                   True
# 5               False                             True                  False
#
# ...

# %%
wf = WeibullFitter()
ef = ExponentialFitter()
lnf = LogNormalFitter()
llf = LogLogisticFitter()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
# Fitting and plotting
for model in [wf, ef, lnf, llf]:
    model.fit(durations = survival_df["tenure"], event_observed = survival_df["churn"])
    model.plot_survival_function()
    print("The AIC value for", model.__class__.__name__, "is",  model.AIC_)
    print("The BIC value for", model.__class__.__name__, "is",  model.BIC_)
    model.print_summary()
    print('='*100)
# Out:
# The AIC value for WeibullFitter is 3216.8611706815464
# The BIC value for WeibullFitter is 3226.676681239511
# <lifelines.WeibullFitter:"Weibull_estimate", fitted with 1000 total observations, 726 right-censored observations>
#    number of observations = 1000
# number of events observed = 274
#            log-likelihood = -1606.43
#                hypothesis = lambda_ != 1, rho_ != 1
#
# ---
#           coef   se(coef)   coef lower 95%   coef upper 95%
# lambda_ 138.09      12.38           113.82           162.36
# rho_      0.95       0.05             0.85             1.05
#
#           cmp to     z      p   -log2(p)
# lambda_     1.00 11.07 <0.005      92.25
# rho_        1.00 -1.07   0.29       1.80
# ---
# AIC = 3216.86
# ...
# The AIC value for ExponentialFitter is 3215.9608134637247
# The BIC value for ExponentialFitter is 3220.868568742707
# <lifelines.ExponentialFitter:"Exponential_estimate", fitted with 1000 total observations, 726 right-censored observations>
# ...

# %% [markdown]
# ### Building models using AFT fitters

# %%
wf_aft = WeibullAFTFitter()
lnf_aft = LogNormalAFTFitter()
llf_aft = LogLogisticAFTFitter()

# %%
#same logic for no zeros
survival_df["tenure"] = np.where(survival_df["tenure"] == 0, 0.000001, survival_df["tenure"])
fig, ax = plt.subplots(figsize=(16, 8))


# Fitting and ploting
i = 1
for model in [wf_aft, lnf_aft, llf_aft]:
    model.fit(survival_df, duration_col = "tenure", event_col = "churn")
    if i == 1:
        label = "WeibullAFTFitter"
    elif i == 2:
        label = "LogNormalAFTFitter"
    elif i == 3:
        label = "LogLogisticAFTFitter"
    i = i + 1
    model.print_summary()
    print('='*100)
    plt.plot(model.predict_survival_function(survival_df.loc[1]), label = label)
    plt.legend()
# Out:
# <lifelines.WeibullAFTFitter: fitted with 1000 total observations, 726 right-censored observations>
#              duration col = 'tenure'
#                 event col = 'churn'
#    number of observations = 1000
# number of events observed = 274
#            log-likelihood = -1462.17
#          time fit was run = 2024-05-01 12:48:16 UTC
#
# ---
#                                           coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# param   covariate
# lambda_ address                           0.04       1.04       0.01             0.02             0.06                 1.02                 1.06
#         age                               0.03       1.03       0.01             0.01             0.04                 1.01                 1.04
#         custcat_E-service                 0.98       2.66       0.16             0.67             1.28                 1.96                 3.61
# ...

# %% [markdown]
# #### The best fitter is the one that has the lowest AIC nad BIC. In our case we can observe that LogNormalFitter performs the best as it has the lowest AIC and BIC scores, moreover its log-likelihood value is the highest. Thus, we will continue with LogNormalFitter as our AFT Fitter.

# %%
logn_aft = LogNormalAFTFitter()
logn_aft.fit(survival_df, duration_col='tenure', event_col='churn')
logn_aft.print_summary()
# Out:
# <lifelines.LogNormalAFTFitter: fitted with 1000 total observations, 726 right-censored observations>
#              duration col = 'tenure'
#                 event col = 'churn'
#    number of observations = 1000
# number of events observed = 274
#            log-likelihood = -1457.01
#          time fit was run = 2024-05-01 12:48:25 UTC
#
# ---
#                                          coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# param  covariate
# mu_    address                           0.04       1.04       0.01             0.03             0.06                 1.03                 1.06
#        age                               0.03       1.03       0.01             0.02             0.05                 1.02                 1.05
#        custcat_E-service                 1.07       2.90       0.17             0.73             1.40                 2.08                 4.06
# ...

# %% [markdown]
# ####  For a feature to significant, it must have a p value of less than 0.05. From the above observations we can claim that address, age, custcat_E-service, custcat_Plus service, custcat_Total service, internet_Yes, marital_Unmarried, voice_Yes are the significant features. At the same time the coefficient's column shows what impact the features have on the survival time of a customer. If the coefficient is positive => increases, if negative=> decreases. So in the survival_df below, I will keep the ones that are significant.

# %%
survival_df = survival_df[["tenure", "churn", "address", "age", "custcat_E-service", "custcat_Plus service", "custcat_Total service", "internet_Yes", "marital_Unmarried", "voice_Yes"]]

# %%
logn_aft = LogNormalAFTFitter()
logn_aft.fit(survival_df, duration_col='tenure', event_col='churn')
logn_aft.print_summary()
# Out:
# <lifelines.LogNormalAFTFitter: fitted with 1000 total observations, 726 right-censored observations>
#              duration col = 'tenure'
#                 event col = 'churn'
#    number of observations = 1000
# number of events observed = 274
#            log-likelihood = -1462.10
#          time fit was run = 2024-05-01 12:48:31 UTC
#
# ---
#                                coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# param  covariate
# mu_    address                 0.04       1.04       0.01             0.03             0.06                 1.03                 1.06
#        age                     0.04       1.04       0.01             0.02             0.05                 1.02                 1.05
#        custcat_E-service       1.03       2.79       0.17             0.69             1.36                 2.00                 3.89
# ...

# %% [markdown]
# ## CLV

# %%
pred_clv = logn_aft.predict_survival_function(survival_df)
pred_clv
# Out:
# ID        1         2         3         4         5         6         7     \
# 1.0   0.999688  0.999736  0.999999  0.997985  0.999870  0.999934  0.996781
# 2.0   0.998129  0.998378  0.999988  0.990703  0.999127  0.999519  0.986180
# 3.0   0.995250  0.995831  0.999956  0.979723  0.997635  0.998631  0.971075
# 4.0   0.991268  0.992267  0.999893  0.966472  0.995448  0.997273  0.953528
# 5.0   0.986400  0.987874  0.999796  0.951860  0.992655  0.995483  0.934724
# ...        ...       ...       ...       ...       ...       ...       ...
# 68.0  0.595597  0.612735  0.941530  0.380751  0.681995  0.740246  0.324647
# 69.0  0.591329  0.608517  0.940235  0.376567  0.678061  0.736667  0.320700
# 70.0  0.587113  0.604347  0.938937  0.372457  0.674164  0.733115  0.316829
# 71.0  0.582946  0.600224  0.937635  0.368420  0.670304  0.729590  0.313033
# 72.0  0.578828  0.596147  0.936331  0.364454  0.666480  0.726092  0.309309
#
# ...

# %%
# keep 1 year
pred = pred_clv.loc[1:12, :]
pred
# Out:
# ID        1         2         3         4         5         6         7     \
# 1.0   0.999688  0.999736  0.999999  0.997985  0.999870  0.999934  0.996781
# 2.0   0.998129  0.998378  0.999988  0.990703  0.999127  0.999519  0.986180
# 3.0   0.995250  0.995831  0.999956  0.979723  0.997635  0.998631  0.971075
# 4.0   0.991268  0.992267  0.999893  0.966472  0.995448  0.997273  0.953528
# 5.0   0.986400  0.987874  0.999796  0.951860  0.992655  0.995483  0.934724
# 6.0   0.980833  0.982817  0.999659  0.936468  0.989349  0.993308  0.915365
# 7.0   0.974715  0.977228  0.999483  0.920676  0.985608  0.990795  0.895877
# 8.0   0.968166  0.971217  0.999264  0.904736  0.981502  0.987984  0.876524
# 9.0   0.961281  0.964870  0.999004  0.888819  0.977091  0.984916  0.857473
# 10.0  0.954136  0.958260  0.998703  0.873040  0.972424  0.981623  0.838827
# 11.0  0.946795  0.951445  0.998361  0.857480  0.967544  0.978136  0.820647
# ...

# %%
MM = 1300
r = 12
for col in range(1, len(pred.columns)+1):
    for row in range(1, 13):
        pred[col][row] = pred[col][row] / (1 + r / 12)**(row - 1)
df['CLV'] = MM * pred.sum(axis = 0)
df.head()
# Out:
# /var/folders/t4/7rdfsxnd2x7_m5hzcqgx9rvc0000gn/T/ipykernel_17742/3160627106.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred[col][row] = pred[col][row] / (1 + r / 12)**(row - 1)
#     region  tenure  age    marital  address  income  \
# ID
# 1   Zone 2      13   44    Married        9      64
# 2   Zone 3      11   33    Married        7     136
# 3   Zone 3      68   52    Married       24     116
# 4   Zone 2      33   33  Unmarried       12      33
# 5   Zone 2      23   30    Married        9      30
#
#                               ed retire  gender voice internet forward  \
# ID
# 1                 College degree     No    Male    No       No     Yes
# 2      Post-undergraduate degree     No    Male   Yes       No     Yes
# ...

# %%
import warnings

warnings.filterwarnings("ignore", message="The figure layout has changed to tight", category=UserWarning)

clv = sns.displot(df, x = 'CLV', kind = 'kde', hue = 'custcat', weights = 16, height=8)
clv.set(title = 'Customer Category CLV density')

# %% [markdown]
# #### From the plot above we can observe that "Plus Service" category customers are the most likely to survive.

# %%
# CLV for customers that left the company within a year
average_clv_left = df["CLV"].loc[(df["tenure"] <= 12) & (df["churn"] == 1)].mean()
print(average_clv_left)

# yearly CLV of cutomers that left
clv_yearly = df["CLV"].loc[(df["tenure"] <= 12) & (df["churn"] == 1)].sum()
print(clv_yearly)
# Out:
# 2515.3173954953
# 264108.3265270065

# %%
pred = pred.T.iloc[:, -1].values

# %%
# I define 0.8 threshold for the survival probability to be considered at risk customer
budget = df["CLV"].loc[(df["tenure"] <= 12) & (pred < 0.8)].sum()
print(budget)
# Out:
# 456937.2851101372

# %% [markdown]
# # Report

# %% [markdown]
# Based on the coefficient of our model we can say that one unit increase in covariate indicates that the mean/median survival time will change by a factor of exp(coefficient). If the coefficient is positive, then the exp(coefficient) will be > 1, which will increase the incident/event time. Similarly, a negative coefficient will reduce the mean/median survival time.Therefore a unit increase in age, address results in increase in survival time by 4%. If a person is unmarried (base = married) then survival time will decrease by 36%, and so on.
# Being a valuable customer means having a high CLV <=> bringing more revenue/provit over their lifetime to the company. Based on the above CLV density plots within different segments I would say that customers that married/not retired/are subscribers of plus service can be considered valuable (gender does not make much difference).
# I defined a threshold of 0.8 for the probability of survival of the customer => if a customer has less than 0.8 prob of survival, then the customer is at-risk. Finally, by summing up the expected values for those customers, we estimate the total annual value of the at-risk subscriber base. This value represents the maximum annual budget that could be spent on retention activities while still generating a positive return on investment.
# There can be several ways to address the retention problem. For instance, improving customer service, offering loyalty programs like special promotions or discounts for some at-risk customers.
